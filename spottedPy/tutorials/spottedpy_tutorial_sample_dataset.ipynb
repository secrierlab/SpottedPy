# %% [markdown]
# # SpottedPy Tutorial

# %% [markdown]
# We will load anndata object in with multiple slides labelled in batch column.
# All signatures and cell types have been labelled in .obs column.

# %%
# !pip install scanpy --upgrade
# !pip install -U libpysal
# !pip install esda
# Out:
# Requirement already satisfied: scanpy in c:\users\ellwi\anaconda3\lib\site-packages (1.9.6)
# Requirement already satisfied: umap-learn>=0.3.10 in c:\users\ellwi\anaconda3\lib\site-packages (from scanpy) (0.5.3)
# Requirement already satisfied: joblib in c:\users\ellwi\anaconda3\lib\site-packages (from scanpy) (1.1.1)
# Requirement already satisfied: numba>=0.41.0 in c:\users\ellwi\anaconda3\lib\site-packages (from scanpy) (0.56.4)
# Requirement already satisfied: tqdm in c:\users\ellwi\anaconda3\lib\site-packages (from scanpy) (4.65.0)
# Requirement already satisfied: scipy>=1.4 in c:\users\ellwi\anaconda3\lib\site-packages (from scanpy) (1.10.1)
# Requirement already satisfied: packaging in c:\users\ellwi\anaconda3\lib\site-packages (from scanpy) (23.0)
# Requirement already satisfied: session-info in c:\users\ellwi\anaconda3\lib\site-packages (from scanpy) (1.0.0)
# Requirement already satisfied: h5py>=3 in c:\users\ellwi\appdata\roaming\python\python39\site-packages (from scanpy) (3.7.0)
# Requirement already satisfied: seaborn!=0.13.0 in c:\users\ellwi\anaconda3\lib\site-packages (from scanpy) (0.12.2)
# Requirement already satisfied: natsort in c:\users\ellwi\anaconda3\lib\site-packages (from scanpy) (8.2.0)
# Requirement already satisfied: networkx>=2.3 in c:\users\ellwi\anaconda3\lib\site-packages (from scanpy) (3.0)
# Requirement already satisfied: matplotlib>=3.4 in c:\users\ellwi\anaconda3\lib\site-packages (from scanpy) (3.7.1)
# Requirement already satisfied: statsmodels>=0.10.0rc2 in c:\users\ellwi\anaconda3\lib\site-packages (from scanpy) (0.13.5)
# Requirement already satisfied: pandas!=2.1.2,>=1.1.1 in c:\users\ellwi\anaconda3\lib\site-packages (from scanpy) (1.5.2)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\ellwi\anaconda3\lib\site-packages (from scanpy) (1.23.5)
# Requirement already satisfied: get-annotations in c:\users\ellwi\anaconda3\lib\site-packages (from scanpy) (0.1.2)
# Requirement already satisfied: anndata>=0.7.4 in c:\users\ellwi\anaconda3\lib\site-packages (from scanpy) (0.8.0)
# Requirement already satisfied: patsy in c:\users\ellwi\anaconda3\lib\site-packages (from scanpy) (0.5.3)
# Requirement already satisfied: scikit-learn>=0.24 in c:\users\ellwi\anaconda3\lib\site-packages (from scanpy) (1.2.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\ellwi\anaconda3\lib\site-packages (from matplotlib>=3.4->scanpy) (5.10.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ellwi\anaconda3\lib\site-packages (from matplotlib>=3.4->scanpy) (9.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ellwi\anaconda3\lib\site-packages (from matplotlib>=3.4->scanpy) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ellwi\anaconda3\lib\site-packages (from matplotlib>=3.4->scanpy) (2.8.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ellwi\anaconda3\lib\site-packages (from matplotlib>=3.4->scanpy) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ellwi\anaconda3\lib\site-packages (from matplotlib>=3.4->scanpy) (1.0.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ellwi\anaconda3\lib\site-packages (from matplotlib>=3.4->scanpy) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\ellwi\anaconda3\lib\site-packages (from matplotlib>=3.4->scanpy) (0.11.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in c:\users\ellwi\anaconda3\lib\site-packages (from numba>=0.41.0->scanpy) (0.39.1)
# Requirement already satisfied: setuptools in c:\users\ellwi\anaconda3\lib\site-packages (from numba>=0.41.0->scanpy) (66.0.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ellwi\anaconda3\lib\site-packages (from pandas!=2.1.2,>=1.1.1->scanpy) (2022.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\ellwi\anaconda3\lib\site-packages (from scikit-learn>=0.24->scanpy) (2.2.0)
# Requirement already satisfied: six in c:\users\ellwi\anaconda3\lib\site-packages (from patsy->scanpy) (1.16.0)
# Requirement already satisfied: pynndescent>=0.5 in c:\users\ellwi\anaconda3\lib\site-packages (from umap-learn>=0.3.10->scanpy) (0.5.8)
# Requirement already satisfied: stdlib-list in c:\users\ellwi\anaconda3\lib\site-packages (from session-info->scanpy) (0.8.0)
# Requirement already satisfied: colorama in c:\users\ellwi\anaconda3\lib\site-packages (from tqdm->scanpy) (0.4.6)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\ellwi\anaconda3\lib\site-packages (from importlib-resources>=3.2.0->matplotlib>=3.4->scanpy) (3.11.0)
# Requirement already satisfied: libpysal in c:\users\ellwi\anaconda3\lib\site-packages (4.8.1)
# Requirement already satisfied: requests in c:\users\ellwi\anaconda3\lib\site-packages (from libpysal) (2.28.1)
# Requirement already satisfied: geopandas>=0.9 in c:\users\ellwi\anaconda3\lib\site-packages (from libpysal) (0.14.0)
# Requirement already satisfied: platformdirs>=2.0.2 in c:\users\ellwi\anaconda3\lib\site-packages (from libpysal) (2.5.2)
# Requirement already satisfied: packaging in c:\users\ellwi\anaconda3\lib\site-packages (from libpysal) (23.0)
# Requirement already satisfied: beautifulsoup4>=4.10 in c:\users\ellwi\anaconda3\lib\site-packages (from libpysal) (4.12.2)
# Requirement already satisfied: numpy>=1.20 in c:\users\ellwi\anaconda3\lib\site-packages (from libpysal) (1.23.5)
# Requirement already satisfied: pandas>=1.4 in c:\users\ellwi\anaconda3\lib\site-packages (from libpysal) (1.5.2)
# Requirement already satisfied: scipy>=1.8 in c:\users\ellwi\anaconda3\lib\site-packages (from libpysal) (1.10.1)
# Requirement already satisfied: shapely>=2 in c:\users\ellwi\anaconda3\lib\site-packages (from libpysal) (2.0.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ellwi\anaconda3\lib\site-packages (from beautifulsoup4>=4.10->libpysal) (2.4)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\ellwi\anaconda3\lib\site-packages (from geopandas>=0.9->libpysal) (3.6.1)
# Requirement already satisfied: fiona>=1.8.21 in c:\users\ellwi\anaconda3\lib\site-packages (from geopandas>=0.9->libpysal) (1.9.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\ellwi\anaconda3\lib\site-packages (from pandas>=1.4->libpysal) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ellwi\anaconda3\lib\site-packages (from pandas>=1.4->libpysal) (2022.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\ellwi\anaconda3\lib\site-packages (from requests->libpysal) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ellwi\anaconda3\lib\site-packages (from requests->libpysal) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ellwi\anaconda3\lib\site-packages (from requests->libpysal) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ellwi\anaconda3\lib\site-packages (from requests->libpysal) (3.4)
# Requirement already satisfied: cligj>=0.5 in c:\users\ellwi\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas>=0.9->libpysal) (0.7.2)
# Requirement already satisfied: six in c:\users\ellwi\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas>=0.9->libpysal) (1.16.0)
# Requirement already satisfied: setuptools in c:\users\ellwi\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas>=0.9->libpysal) (66.0.0)
# Requirement already satisfied: importlib-metadata in c:\users\ellwi\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas>=0.9->libpysal) (6.0.0)
# Requirement already satisfied: click~=8.0 in c:\users\ellwi\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas>=0.9->libpysal) (8.0.4)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\ellwi\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas>=0.9->libpysal) (22.1.0)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\ellwi\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas>=0.9->libpysal) (1.1.1)
# Requirement already satisfied: colorama in c:\users\ellwi\anaconda3\lib\site-packages (from click~=8.0->fiona>=1.8.21->geopandas>=0.9->libpysal) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in c:\users\ellwi\anaconda3\lib\site-packages (from importlib-metadata->fiona>=1.8.21->geopandas>=0.9->libpysal) (3.11.0)
# Requirement already satisfied: esda in c:\users\ellwi\anaconda3\lib\site-packages (2.5.1)
# Requirement already satisfied: libpysal in c:\users\ellwi\anaconda3\lib\site-packages (from esda) (4.8.1)
# Requirement already satisfied: pandas>1.4 in c:\users\ellwi\anaconda3\lib\site-packages (from esda) (1.5.2)
# Requirement already satisfied: scikit-learn>=1.0 in c:\users\ellwi\anaconda3\lib\site-packages (from esda) (1.2.2)
# Requirement already satisfied: scipy>=1.9 in c:\users\ellwi\anaconda3\lib\site-packages (from esda) (1.10.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ellwi\anaconda3\lib\site-packages (from pandas>1.4->esda) (2022.7)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\ellwi\anaconda3\lib\site-packages (from pandas>1.4->esda) (1.23.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\ellwi\anaconda3\lib\site-packages (from pandas>1.4->esda) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\ellwi\anaconda3\lib\site-packages (from scikit-learn>=1.0->esda) (2.2.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\ellwi\anaconda3\lib\site-packages (from scikit-learn>=1.0->esda) (1.1.1)
# Requirement already satisfied: beautifulsoup4>=4.10 in c:\users\ellwi\anaconda3\lib\site-packages (from libpysal->esda) (4.12.2)
# Requirement already satisfied: geopandas>=0.9 in c:\users\ellwi\anaconda3\lib\site-packages (from libpysal->esda) (0.14.0)
# Requirement already satisfied: platformdirs>=2.0.2 in c:\users\ellwi\anaconda3\lib\site-packages (from libpysal->esda) (2.5.2)
# Requirement already satisfied: requests in c:\users\ellwi\anaconda3\lib\site-packages (from libpysal->esda) (2.28.1)
# Requirement already satisfied: shapely>=2 in c:\users\ellwi\anaconda3\lib\site-packages (from libpysal->esda) (2.0.2)
# Requirement already satisfied: packaging in c:\users\ellwi\anaconda3\lib\site-packages (from libpysal->esda) (23.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ellwi\anaconda3\lib\site-packages (from beautifulsoup4>=4.10->libpysal->esda) (2.4)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\ellwi\anaconda3\lib\site-packages (from geopandas>=0.9->libpysal->esda) (3.6.1)
# Requirement already satisfied: fiona>=1.8.21 in c:\users\ellwi\anaconda3\lib\site-packages (from geopandas>=0.9->libpysal->esda) (1.9.5)
# Requirement already satisfied: six>=1.5 in c:\users\ellwi\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>1.4->esda) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ellwi\anaconda3\lib\site-packages (from requests->libpysal->esda) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ellwi\anaconda3\lib\site-packages (from requests->libpysal->esda) (1.26.15)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\ellwi\anaconda3\lib\site-packages (from requests->libpysal->esda) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ellwi\anaconda3\lib\site-packages (from requests->libpysal->esda) (2022.12.7)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\ellwi\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas>=0.9->libpysal->esda) (22.1.0)
# Requirement already satisfied: importlib-metadata in c:\users\ellwi\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas>=0.9->libpysal->esda) (6.0.0)
# Requirement already satisfied: cligj>=0.5 in c:\users\ellwi\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas>=0.9->libpysal->esda) (0.7.2)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\ellwi\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas>=0.9->libpysal->esda) (1.1.1)
# Requirement already satisfied: click~=8.0 in c:\users\ellwi\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas>=0.9->libpysal->esda) (8.0.4)
# Requirement already satisfied: setuptools in c:\users\ellwi\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas>=0.9->libpysal->esda) (66.0.0)
# Requirement already satisfied: colorama in c:\users\ellwi\anaconda3\lib\site-packages (from click~=8.0->fiona>=1.8.21->geopandas>=0.9->libpysal->esda) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in c:\users\ellwi\anaconda3\lib\site-packages (from importlib-metadata->fiona>=1.8.21->geopandas>=0.9->libpysal->esda) (3.11.0)

# %%
import scanpy as sc
import anndata as ad
import os
import numpy as np
import sys
#sys.path.append(r"C:\Users\ellwi\Documents\GitHub\Sp\spottedPy")

import spottedpy as sp
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import squidpy as sq
from tqdm import tqdm

# %% [markdown]
# Read in anndata file (anndata_one_slide_tutorial.h5ad) and ensure columns we are interested in calculating hotspots from are labelled in .obs column and fill the columns without the labels with nan to ensure create_hotspot does not use these values for hotspot creation. Ensure batch is labelled as a string.

# %% [markdown]
# Data available: [zenodo_link](https://zenodo.org/records/10392317)

# %%
#read in anndata visium object
#data called anndata_one_slide_tutorial.h5ad, and found in GitHub and zenodo link
path="path/to/file"
anndata_breast=sc.read_h5ad(path)

# %% [markdown]
# # 1) Hotspot analysis

# %%
#It is the values in the .obs columns that we are interested in calculating hotspots from
TME_labels=['hypoxia_hallmarks', 'angio_hallmarks', 'Macrophage']
tumour_labels=['EMT_hallmarks','cell_prolif']

# %% [markdown]
# Create hotspots for our EMT values and TME values. Hotspot and coldspots labels are found in .obs of anndata. Ensure scores are in the range of 0 to 1. relative_to_batch=True (default) ensures that the hotspot scores are calculated within each batch, useful for experiments with no change in condition (and batch correction does not need to be performed). However, if there is a change in condition, relative_to_batch=False could be used to understand more global changes, but batch correction should be performed first.
#
# ```python

# %%
for i in tqdm(TME_labels):
    anndata_breast=sp.create_hotspots(anndata_breast,column_name=i,neighbours_parameters=10,relative_to_batch=True)
#ensure we calculate hotspot from just tumour cells for emt_hallmarks
for i in tqdm(tumour_labels):
    anndata_breast=sp.create_hotspots(anndata_breast,filter_columns="tumour_cells",filter_value=1,column_name=i,neighbours_parameters=10,relative_to_batch=True)
# Out:
# 100%|██████████| 3/3 [00:22<00:00,  7.41s/it]
# 100%|██████████| 2/2 [00:01<00:00,  1.73it/s]

# %%
#loop through TME_labels and add "_hot" to the end of each one so we calculate distances from them
TME_labels_hotspots=TME_labels.copy()
for i in range(0,len(TME_labels)):
    TME_labels_hotspots[i]=TME_labels[i]+'_hot'

# %% [markdown]
# Calculate distances from selected variables of interest.
# Default to max distance, means that for the primary variables of interest (hotspots we calculate distance from), if there is not a comparison variable hotspot within the slide, the distance is set to the max distance. If false, then no distance is recorded which may bias the data.
# ```python

# %%
#primary variables are the hotspots we calculate distances from
#comparison variables are the hotspots we calculate distances to
primary_variables_values=['EMT_hallmarks_hot', 'EMT_hallmarks_cold']
#add 'cell_prolif_hot' to the comparison variables
TME_labels_hotspots.append('cell_prolif_hot')
distances=sp.calculateDistances(anndata_breast,primary_variables=primary_variables_values,comparison_variables=TME_labels_hotspots,empty_hotspot_default_to_max_distance=True)

# %% [markdown]
# Plot mean distances from primary variables to comparison variables.

# %%
sp.plot_bubble_plot_mean_distances(distances,primary_vars=primary_variables_values,
                                        comparison_vars=TME_labels_hotspots,fig_size=(5,5))

# %% [markdown]
# Plot distribution of distances. Plots per comparison variable.

# %%
sp.plot_bar_plot_distance(distances,primary_variables=primary_variables_values,comparison_variables=['hypoxia_hallmarks_hot','angio_hallmarks_hot'],fig_size=(3,3))

# %% [markdown]
# Plot hotspots on each slide.

# %%
sp.plot_hotspots(anndata_breast,column_name="hypoxia_hallmarks_hot")

# %% [markdown]
# Choose two primary variables to compare in a comparison scatter plot.

# %% [markdown]
# First value in primary_vars will be variable we subtract distances from for comparison. Therefore negative value means first primary variable is closer to comparison variable, and a positive value means that the second primary variable is closer to the comparison variable.

# %%
sp.plot_custom_scatter(data=distances, primary_vars=["EMT_hallmarks_hot","EMT_hallmarks_cold"], comparison_vars=TME_labels_hotspots, bubble_size=(400,400),file_path_plots=None, fig_size=(6, 5))

# %% [markdown]
# Above, we can see that angiogenic hotspots are the closest hotspots to EMT hotspots, followed by hypoxia hotspots.

# %% [markdown]
# # Signature scoring

# %% [markdown]
# Measuring gene signature scores in hotspots and compare scores within the hotspots.

# %%
response_to_check_point=['STAT1','CCR5','CXCL9','CXCL10','CXCL11','PRF1','GZMA','HLA-DRA']
gene_lists = [response_to_check_point]  # List of genes for each signature
gene_list_names = ['response_to_check_point']  # Names for each gene list
states_to_loop_through = ['EMT_hallmarks_hot', 'EMT_hallmarks_cold']  # States to be analyzed
anndata_breast, signatures = sp.score_genes_by_batch(anndata_breast, gene_lists, gene_list_names)
#return data so we can perform further analysis
sp.plot_gene_heatmap(anndata_breast, signatures, states_to_loop_through, plot_score=True, normalize_values=False,fig_size=(3,3))
# Out:
# c:\Users\ellwi\anaconda3\lib\site-packages\scanpy\tools\_score_genes.py:175: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   adata.obs[score_name] = pd.Series(
#                     response_to_check_point_score
# EMT_hallmarks_hot                        3.257907
# EMT_hallmarks_cold                       0.187900

# %%
sp.plot_signature_boxplot(anndata_breast,hotspot_variable=['EMT_hallmarks_hot','EMT_hallmarks_cold'],signature='response_to_check_point_score',fig_size=(5,3))

# %% [markdown]
# # Sensitivity Analysis

# %% [markdown]
# Lets increase hypoxia, angiogenesis and emt hotspot size and see how relationship changes. Variable names (before _hot/_cold) need to be defined in .obs of anndata
#
#         params['variable_comparison'] is the variable that is being compared to the other variables
#         - params (dict): A dictionary with the following keys:
#         * 'variable_comparison' (str): Name of the variable used for comparison.
#         * 'variable_comparison_tumour' (bool): Indicates if data should be filtered for tumor cells for 'variable_comparison'.
#         * 'sensitivity_parameter' (str): Specifies the sensitivity analysis parameter type ('pvalue' or 'neighbourhood').
#         * 'variable_one' (str), 'variable_two' (str): Names of primary variables for distance calculation.
#         * 'variable_one_two_is_tumour' (bool): Indicates if data should be filtered for tumor cells for 'variable_one' and 'variable_two'.
#         * 'variable_three' (str): Reference variable for distance calculation. E.g .obs['tumour_cells']. Do not calculate hotspot for this. Remember: values in .obs in column without reference value should be nan.
#         * 'values_to_test' (list): List of values to test for the sensitivity analysis.
#         * 'file_name' (str): Name of the file to save the plot.
#         * 'variable_comparison_constant' (bool): Indicates if the comparison variable should be varied.

# %%
"""
#e.g. testing pvalue
params = {
    'variable_comparison': "macrophage_hot",
    'variable_one': "EMT_hallmarks_hot",
    'variable_two': "EMT_hallmarks_cold",
    #reference value, i.e. no hotspots calculated from it
    'variable_three': "tumour_cells",
    'values_to_test': [0.001,0.005,0.01,0.05,0.1,0.2],
    'variable_comparison_constant': True,
    'variable_comparison_tumour': False,
    'variable_one_two_is_tumour': True,
    'file_name': "sensitivity_plot_macrophage",
    'sensitivity_parameter': "pvalue"
}
"""

#testing neighbourhood
params = {
    'variable_comparison': "Macrophage_hot",
    'variable_one': "EMT_hallmarks_hot",
    'variable_two': "EMT_hallmarks_cold",
    #reference value, i.e. no hotspots calculated from it
    'variable_three': "tumour_cells",
    'values_to_test': [1,2,5,10,20,50],
    'variable_comparison_constant': True,
    'variable_comparison_tumour': False,
    'variable_one_two_is_tumour': True,
    'file_name': "sensitivity_plot_macrophage",
    'sensitivity_parameter': "neighbourhood"
}
results = sp.sensitivity_calcs(anndata_breast, params)
# Out:
# meta NOT subset; don't know how to subset; dropped

# %%
#differences per batch (i.e. slide)
#returns distances for further analysis if needed
data=sp.plot_bubble_chart_by_batch(distances, primary_variable_value='EMT_hallmarks_hot',
                               comparison_variable_values=TME_labels_hotspots,
                               reference_variable="EMT_hallmarks_cold",
                               save_path="bubble_chart_by_batch.pdf",
                               pval_cutoff=0.05,
                               fig_size=(5,5))
# Out:
# C:\Users\ellwi\Documents\GitHub\Sp\spottedPy\spottedpy.py:789: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels, rotation=90)
# meta NOT subset; don't know how to subset; dropped

# %% [markdown]
# # 2) Neighbourhood correlation (correlate signatures within different neighbourhood settings)

# %% [markdown]
# Given the source_nodes (here filtered for tumour spots), we can calculate the correlation between signatures in the neighbourhood of each source node. Rings range specifies spatial unit.

# %%
#results (dict): A dictionary where each key is the number of rings used for neighbor calculation, and each  value is a tuple containing the correlation matrix and the corresponding p-values matrix for those rings.
results = sp.calculate_neighbourhood_correlation(rings_range=[1,2,3], 
                                                           adata_vis=anndata_breast,
                                                           neighbour_variables=anndata_breast.obs[['EMT_hallmarks', 'hypoxia_hallmarks', 'angio_hallmarks', 'Macrophage', 'cell_prolif']],
                                                           source_nodes=anndata_breast[anndata_breast.obs['tumour_cells']==1].obs.index)
# Out:
# 100%|██████████| 953/953 [00:00<00:00, 1487.58it/s]
# 100%|██████████| 953/953 [00:00<00:00, 1295.69it/s]
# 100%|██████████| 953/953 [00:00<00:00, 1498.59it/s]

# %%
#select ring number to plot as a heatmap
sp.correlation_heatmap_neighbourhood(results[1], 'EMT_hallmarks', 'hypoxia_hallmarks', 'angio_hallmarks', 'Macrophage','cell_prolif',path_to_save="test.pdf",fig_size=(5,5))
# Out:
# meta NOT subset; don't know how to subset; dropped

# %%
sp.plot_correlation_shifts(results,correlation_primary_variable='EMT_hallmarks',file_path="correlation_shifts.pdf")
# Out:
# meta NOT subset; don't know how to subset; dropped

# %%
sp.plot_overall_change(results,correlation_primary_variable='EMT_hallmarks',file_path="overall_change.pdf",fig_size=(5,5))
# Out:
# meta NOT subset; don't know how to subset; dropped

# %% [markdown]
# # Correlate inner ring with outer ring (neighbourhood enrichment)

# %% [markdown]
# Takes longer than above. A different spatial unit approach, correlate inner ring with outer ring. Specify inner nodes for correlation e.g. tumour cells

# %%
results_inner_outer=sp.calculate_inner_outer_neighbourhood_enrichment(rings_range=[1,2,3,5,10],adata_vis=anndata_breast,
                                                                           neighbour_variables=anndata_breast.obs[['EMT_hallmarks', 'hypoxia_hallmarks', 'angio_hallmarks', 'macrophage', 'nk_cells']],
                                                                           source_nodes=anndata_breast[anndata_breast.obs['tumour_cells']==1].obs.index)

# %%
#using cell abundance from calculate_inner_outer_neighbourhood_enrichment, we calculate corr_df and pval that we can use to plot using functions previoulsy defined
#correlation_key_variable is the inner ring variable we want to correlate with the other variables in the outer rings
results_corr=sp.calculate_corr_pvalue_for_inner_outer_neighbourhood_enrichment(results_inner_outer,
                                                                               correlation_key_variable=['EMT_hallmarks'],
                                                                               rings_range=[1,2,3,5,10])

# %%
sp.plot_correlation_shifts(results,correlation_primary_variable='EMT_hallmarks',file_path="correlation_shifts_inner_outer.pdf")
